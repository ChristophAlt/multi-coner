# %%
# %load_ext autoreload
# %autoreload 2

import sys

sys.path.append("../")

# %%
RUNS_PATH = "/media/christoph/HDD/experiments/multi_coner_remote/multiruns/"

# %%
import json
import wandb

from pathlib import Path
from omegaconf import OmegaConf
from itertools import chain

# %%
def runs_as_dicts(path: str):
    path = Path(path)
    
    run_directories = [p.parent for p in path.glob("**/config_tree.txt")]
    
    run_dicts = []
    for directory in run_directories:
        hydra_directory = directory / ".hydra"
        wandb_directory = directory / "wandb"
        
        hydra_config_file = hydra_directory / "config.yaml"
        
        assert hydra_config_file.exists()
        
        wandb_run_directories = list(wandb_directory.glob("run-*"))
        
        if len(wandb_run_directories) != 1:
            print("No wandb run directory found in ", directory)
            continue
        
        wandb_run_directory = wandb_run_directories[0]
        
        wandb_run_id = wandb_run_directory.name.split("-")[-1]
        
        wandb_files_directory = wandb_run_directory / "files"
        
        wandb_metadata_file = wandb_files_directory / "wandb-metadata.json"
        wandb_summary_file = wandb_files_directory / "wandb-summary.json"
        
        assert wandb_metadata_file.exists()
        assert wandb_summary_file.exists()
        
        validation_file = directory / "checkpoints" / "validation_result.json"
        augmented_validation_file = directory / "checkpoints" / "augm_validation_result.json"
        
        assert validation_file.exists()
        assert augmented_validation_file.exists()
        
        hydra_config = OmegaConf.load(hydra_config_file)
        
        with wandb_metadata_file.open() as f:
            wandb_metadata = json.load(f)
        
        with wandb_summary_file.open() as f:
            wandb_summary = json.load(f)
        
        with validation_file.open() as f:
            validation_result = json.load(f)
        
        with augmented_validation_file.open() as f:
            augmented_validation_result = json.load(f)
        
        run_dict = {
            "wandb": {
                "id": wandb_run_id,
                "metadata": wandb_metadata,
                "summary": wandb_summary,
            },
            "hydra": OmegaConf.to_container(hydra_config, resolve=False),
            "validation": {
                "original": validation_result,
                "augmented": augmented_validation_result,
            }
        }
        
        run_dicts.append(run_dict)
    
    return run_dicts

# %%
run_dicts = runs_as_dicts(RUNS_PATH)
# Out:
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/29
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/10
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/11
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/12
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/13
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/14
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/15
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/24
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/25
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/26
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/27
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/28
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/30
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/31
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/40
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/41
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/42
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/43
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/44
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/45
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/46
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/47
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/56
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/57
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/58
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/59
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/60
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/61
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/62
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/63
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/8
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/9
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-11_00-06-08/0
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-11_00-07-35/0
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-14_14-10-47/0

# %%
import pandas as pd

# %%
def run_dicts_to_dataframe(run_dicts):
    table = []
    for run_dict in run_dicts:
        table_row = {"id": run_dict["wandb"]["id"]}
        
        validation_metrics = [(f"val/orig/{key}", value) for key, value in run_dict["validation"]["original"]["macro avg"].items()]
        
        table_row.update(validation_metrics)
        
        augmented_validation_metrics = [(f"val/augm/{key}", value) for key, value in run_dict["validation"]["augmented"]["macro avg"].items()]
    
        table_row.update(augmented_validation_metrics)
        
        wandb_metrics = [(metric, val) for metric, val in run_dict["wandb"]["summary"].items() if not metric.startswith("_")]

        table_row.update(wandb_metrics)
    
        hydra_config = run_dict["hydra"]
    
        table_row["batch_size"] = hydra_config["datamodule"]["batch_size"]
        
        hydra_metrics = [(f"{config_key}_target", val) if key == "_target_" else (key, val) for config_key in ["datamodule", "taskmodule", "model"] for key, val in hydra_config[config_key].items()]
    
        table_row.update(hydra_metrics)
    
        table.append(table_row)
    
    return pd.DataFrame(table)

# %%
df = run_dicts_to_dataframe(run_dicts)

# %%
df.sort_values(by="val/f1", ascending=False)[:50][[
    "id", "val/f1", "val/orig/f1-score", "val/augm/f1-score", "train/f1", "batch_size", "learning_rate", "task_learning_rate", "wiki_to_vec_file",
    "gazetteer_add_output_features", "gazetteer_add_input_tokens", "gazetteer_path", "augment_input", "augment_input_prob", "use_mlp",
    "mlp_hidden_dim", "mlp_num_layers", "model_name_or_path", "use_span_length_embedding", "use_language_model"]]
# Out:
#            id    val/f1  val/orig/f1-score  val/augm/f1-score  train/f1  \
# 77   189dh04u  0.910423           0.903801           0.892559  0.945358
# 8    tkoj95qs  0.909843           0.900480           0.884286  0.892003
# 123  30h3uizb  0.899585           0.888922           0.833542  0.988594
# 121  10cd4j62  0.896945           0.890265           0.833772  0.985201
# 26   34bizri5  0.891947           0.885088           0.829004  0.974973
# 19   16mclf9r  0.891033           0.886239           0.840657  0.924516
# 20   1yfizu0u  0.890631           0.881313           0.827188  0.971660
# 35   2iwqh41v  0.889072           0.879458           0.842795  0.981810
# 14   3ktl34lz  0.888166           0.874650           0.817828  0.963562
# 27   1nwj2ove  0.886831           0.876612           0.835322  0.855188
# 45   wtnsnols  0.880232           0.866294           0.834513  0.843533
# 118  3krpp4o3  0.879484           0.872284           0.814090  0.970487
# 18   1r26cmz0  0.873362           0.876278           0.827763  0.971324
# 119  2jrs3n6g  0.871417           0.869005           0.819450  0.984759
# 89   y94w2aik  0.871009           0.851505           0.845741  0.889114
# 50   1d3m9qnz  0.853933           0.836152           0.835803  0.890685
# 28   vx8lf2w2  0.850652           0.831026           0.791935  0.895497
# 60   2gkhd1tl  0.835871           0.820413           0.832822  0.864967
# 70   3699dtwr  0.684337           0.689822           0.705209  0.726031
# 7    2tkbf0t7  0.676343           0.654950           0.665195  0.697023
# 74   2tw8n17c  0.675238           0.812931           0.813672  0.680318
# 54   1vnj45iv  0.673152           0.661857           0.672734  0.700680
# 6    i39wwdzc  0.668645           0.642364           0.650893  0.693990
# 48   3jtpy5hh  0.667324           0.647811           0.658543  0.692249
# 57   3kmkglwp  0.664659           0.656082           0.665190  0.735748
# 80   3ad0do62  0.664036           0.657154           0.669851  0.703996
# 63   xz8bzijt  0.664028           0.654207           0.665748  0.742810
# 85   2xt997wl  0.664020           0.646156           0.658671  0.703873
# 52   2p8sfyt8  0.662716           0.644006           0.654258  0.701959
# 81   21ymy6pl  0.662698           0.659465           0.673721  0.703107
# 59   3gwjpchu  0.662049           0.653313           0.662791  0.696577
# 84   1s11akcf  0.660732           0.663728           0.674601  0.747222
# 78   2grudinm  0.660040           0.632746           0.640847  0.693803
# 79   3mz9cpks  0.659373           0.632332           0.640868  0.693226
# 5    3w4nacko  0.658039           0.631443           0.639458  0.688135
# 10   211od120  0.656672           0.631114           0.638980  0.675911
# 55   3chg60sn  0.656048           0.656188           0.666941  0.702019
# 38   1bzr29sb  0.655802           0.638478           0.649794  0.655745
# 82   1nec0ln7  0.655672           0.633585           0.639486  0.719782
# 104  3926lmpx  0.655555           0.642418           0.649290  0.736266
# 88   11z12asf  0.654726           0.632991           0.642354  0.690984
# 49   1m8ou9gy  0.654691           0.628120           0.635876  0.694038
# 61   3utueic8  0.654057           0.634034           0.641427  0.703004
# 111  2peh20to  0.653712           0.632739           0.641071  0.712580
# 107  2gnfe1ac  0.652938           0.618658           0.626446  0.692515
# 100  q9pjprzh  0.652525           0.648896           0.659668  0.718586
# 56   rmt2s7k1  0.651978           0.653664           0.667456  0.714790
# 69   3ne9vz94  0.651662           0.645051           0.654718  0.716866
# 62   2naphsvn  0.651606           0.638499           0.647047  0.704924
# 39   3th4m8vd  0.651530           0.624491           0.632541  0.654757
#
#      batch_size  learning_rate  task_learning_rate  \
# 77           16       0.000010            0.000050
# 8            16       0.000010            0.000100
# 123          32       0.000010            0.000050
# 121          32       0.000010            0.000050
# 26           32       0.000010            0.000100
# 19           32       0.000050            0.000010
# 20           32       0.000010            0.000010
# 35           32       0.000050            0.000100
# 14           32       0.000010            0.000010
# 27           32       0.000010            0.000100
# 45           32       0.000010            0.000010
# 118          32       0.000010            0.000050
# 18           32       0.000050            0.000010
# 119          32       0.000010            0.000050
# 89           32       0.000030            0.000050
# 50           16       0.000032            0.000250
# 28           32       0.000010            0.000100
# 60           16       0.000033            0.000203
# 70           32       0.000083            0.000466
# 7             8       0.000100            0.000100
# 74           16       0.000031            0.000196
# 54           32       0.000014            0.000283
# 6             8       0.000050            0.000100
# 48           32       0.000045            0.000329
# 57           32       0.000025            0.000326
# 80           16       0.000010            0.000300
# 63           16       0.000049            0.000255
# 85           16       0.000050            0.000300
# 52           16       0.000052            0.000428
# 81           16       0.000010            0.000300
# 59           32       0.000076            0.000490
# 84           16       0.000050            0.000300
# 78           16       0.000050            0.000100
# 79           16       0.000050            0.000100
# 5             8       0.000010            0.000100
# 10           16       0.000100            0.000100
# 55           16       0.000067            0.000405
# 38           32       0.000050            0.000100
# 82           16       0.000030            0.000300
# 104          32       0.000050            0.000300
# 88           16       0.000030            0.000050
# 49           16       0.000012            0.000171
# 61           16       0.000041            0.000203
# 111          16       0.000030            0.000100
# 107          16       0.000050            0.000050
# 100          32       0.000010            0.000300
# 56           16       0.000058            0.000256
# 69           32       0.000066            0.000455
# 62           16       0.000021            0.000132
# 39           32       0.000050            0.000100
#
#                                       wiki_to_vec_file  \
# 77   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 8    /vol/home-vol2/ml/altchris/projects/multi-cone...
# 123  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 121  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 26   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 19   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 20   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 35   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 14   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 27   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 45   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 118                                               None
# 18   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 119                                               None
# 89   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 50   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 28   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 60   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 70   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 7    /vol/home-vol2/ml/altchris/projects/multi-cone...
# 74   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 54   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 6    /vol/home-vol2/ml/altchris/projects/multi-cone...
# 48   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 57   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 80   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 63   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 85   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 52   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 81   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 59   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 84   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 78   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 79   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 5    /vol/home-vol2/ml/altchris/projects/multi-cone...
# 10   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 55   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 38   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 82   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 104  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 88   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 49   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 61   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 111  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 107  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 100  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 56   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 69   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 62   /vol/home-vol2/ml/altchris/projects/multi-cone...
# 39   /vol/home-vol2/ml/altchris/projects/multi-cone...
#
#      gazetteer_add_output_features  gazetteer_add_input_tokens  \
# 77                            True                        True
# 8                             True                        True
# 123                          False                       False
# 121                          False                       False
# 26                           False                       False
# 19                            True                       False
# 20                            True                       False
# 35                           False                       False
# 14                           False                       False
# 27                           False                       False
# 45                            True                        True
# 118                          False                       False
# 18                            True                       False
# 119                          False                       False
# 89                            True                        True
# 50                            True                        True
# 28                            True                       False
# 60                            True                        True
# 70                            True                        True
# 7                             True                        True
# 74                            True                        True
# 54                            True                        True
# 6                             True                        True
# 48                            True                        True
# 57                            True                        True
# 80                            True                        True
# 63                            True                        True
# 85                            True                        True
# 52                            True                        True
# 81                            True                        True
# 59                            True                        True
# 84                            True                        True
# 78                            True                        True
# 79                            True                        True
# 5                             True                        True
# 10                            True                        True
# 55                            True                        True
# 38                            True                       False
# 82                            True                        True
# 104                           True                        True
# 88                            True                        True
# 49                            True                        True
# 61                            True                        True
# 111                           True                        True
# 107                           True                        True
# 100                           True                        True
# 56                            True                        True
# 69                            True                        True
# 62                            True                        True
# 39                            True                       False
#
#                                         gazetteer_path  augment_input  \
# 77   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 8    /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 123                                               None          False
# 121                                               None          False
# 26   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 19   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 20   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 35   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 14   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 27   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 45   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 118                                               None          False
# 18   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 119                                               None          False
# 89   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 50   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 28   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 60   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 70   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 7    /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 74   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 54   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 6    /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 48   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 57   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 80   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 63   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 85   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 52   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 81   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 59   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 84   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 78   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 79   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 5    /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 10   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 55   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 38   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 82   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 104  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 88   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 49   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 61   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 111  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 107  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 100  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 56   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 69   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 62   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 39   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
#
#      augment_input_prob  use_mlp  mlp_hidden_dim  mlp_num_layers  \
# 77             0.300000     True            1024               2
# 8              0.200000     True            1024               2
# 123            0.200000     True            1024               2
# 121            0.200000     True            1024               2
# 26             0.200000     True            1024               2
# 19             0.200000     True            1024               2
# 20             0.200000     True            1024               2
# 35             0.200000     True            1024               2
# 14             0.200000     True            1024               2
# 27             0.200000     True            1024               2
# 45             0.200000     True            1024               2
# 118            0.200000     True            1024               2
# 18             0.200000     True            1024               2
# 119            0.200000     True            1024               2
# 89             0.200000     True            1024               2
# 50             0.323977     True             128               2
# 28             0.200000     True            1024               2
# 60             0.142144     True             512               2
# 70             0.230234     True            1024               2
# 7              0.200000     True            1024               2
# 74             0.138387     True             512               2
# 54             0.211416     True            1024               2
# 6              0.200000     True            1024               2
# 48             0.261817     True             128               2
# 57             0.226294     True            1024               2
# 80             0.200000     True            1024               2
# 63             0.126006     True            1024               2
# 85             0.300000     True            1024               2
# 52             0.324056     True             128               2
# 81             0.300000     True            1024               2
# 59             0.303388     True             128               2
# 84             0.200000     True            1024               2
# 78             0.200000     True            1024               2
# 79             0.300000     True            1024               2
# 5              0.200000     True            1024               2
# 10             0.200000     True            1024               2
# 55             0.351576     True             128               2
# 38             0.200000     True            1024               2
# 82             0.200000     True            1024               2
# 104            0.200000     True            1024               2
# 88             0.200000     True            1024               2
# 49             0.226998     True             512               2
# 61             0.175424     True             512               2
# 111            0.300000     True            1024               2
# 107            0.300000     True            1024               2
# 100            0.200000     True            1024               2
# 56             0.263506     True            1024               2
# 69             0.485859     True             256               2
# 62             0.186278     True             512               2
# 39             0.200000     True            1024               2
#
#                      model_name_or_path use_span_length_embedding  \
# 77   google/electra-large-discriminator                       NaN
# 8    google/electra-large-discriminator                       NaN
# 123  google/electra-large-discriminator                      True
# 121  google/electra-large-discriminator                      True
# 26   google/electra-large-discriminator                       NaN
# 19   google/electra-large-discriminator                       NaN
# 20   google/electra-large-discriminator                       NaN
# 35   google/electra-large-discriminator                       NaN
# 14   google/electra-large-discriminator                       NaN
# 27   google/electra-large-discriminator                       NaN
# 45   google/electra-large-discriminator                       NaN
# 118  google/electra-large-discriminator                      True
# 18   google/electra-large-discriminator                       NaN
# 119  google/electra-large-discriminator                      True
# 89   google/electra-large-discriminator                       NaN
# 50   google/electra-large-discriminator                       NaN
# 28   google/electra-large-discriminator                       NaN
# 60   google/electra-large-discriminator                       NaN
# 70   google/electra-large-discriminator                       NaN
# 7    google/electra-large-discriminator                       NaN
# 74   google/electra-large-discriminator                       NaN
# 54   google/electra-large-discriminator                       NaN
# 6    google/electra-large-discriminator                       NaN
# 48   google/electra-large-discriminator                       NaN
# 57   google/electra-large-discriminator                       NaN
# 80   google/electra-large-discriminator                       NaN
# 63   google/electra-large-discriminator                       NaN
# 85   google/electra-large-discriminator                       NaN
# 52   google/electra-large-discriminator                       NaN
# 81   google/electra-large-discriminator                       NaN
# 59   google/electra-large-discriminator                       NaN
# 84   google/electra-large-discriminator                       NaN
# 78   google/electra-large-discriminator                       NaN
# 79   google/electra-large-discriminator                       NaN
# 5    google/electra-large-discriminator                       NaN
# 10   google/electra-large-discriminator                       NaN
# 55   google/electra-large-discriminator                       NaN
# 38   google/electra-large-discriminator                       NaN
# 82   google/electra-large-discriminator                       NaN
# 104  google/electra-large-discriminator                       NaN
# 88   google/electra-large-discriminator                       NaN
# 49   google/electra-large-discriminator                       NaN
# 61   google/electra-large-discriminator                       NaN
# 111  google/electra-large-discriminator                       NaN
# 107  google/electra-large-discriminator                       NaN
# 100  google/electra-large-discriminator                       NaN
# 56   google/electra-large-discriminator                       NaN
# 69   google/electra-large-discriminator                       NaN
# 62   google/electra-large-discriminator                       NaN
# 39   google/electra-large-discriminator                       NaN
#
#     use_language_model
# 77                 NaN
# 8                  NaN
# 123               True
# 121               True
# 26                 NaN
# 19                 NaN
# 20                 NaN
# 35                 NaN
# 14                 NaN
# 27                 NaN
# 45                 NaN
# 118               True
# 18                 NaN
# 119               True
# 89                 NaN
# 50                 NaN
# 28                 NaN
# 60                 NaN
# 70                 NaN
# 7                  NaN
# 74                 NaN
# 54                 NaN
# 6                  NaN
# 48                 NaN
# 57                 NaN
# 80                 NaN
# 63                 NaN
# 85                 NaN
# 52                 NaN
# 81                 NaN
# 59                 NaN
# 84                 NaN
# 78                 NaN
# 79                 NaN
# 5                  NaN
# 10                 NaN
# 55                 NaN
# 38                 NaN
# 82                 NaN
# 104                NaN
# 88                 NaN
# 49                 NaN
# 61                 NaN
# 111                NaN
# 107                NaN
# 100                NaN
# 56                 NaN
# 69                 NaN
# 62                 NaN
# 39                 NaN

# %%
df.columns
# Out:
# Index(['id', 'val/orig/f1-score', 'val/orig/precision', 'val/orig/recall',
#        'val/orig/support', 'val/augm/f1-score', 'val/augm/precision',
#        'val/augm/recall', 'val/augm/support', 'train/loss_step', 'epoch',
#        'trainer/global_step', 'val/loss', 'val/f1', 'train/loss_epoch',
#        'train/f1', 'batch_size', 'datamodule_target', 'data_dir', 'name',
#        'num_workers', 'pin_memory', 'taskmodule_target',
#        'tokenizer_name_or_path', 'entity_annotation', 'padding', 'truncation',
#        'max_length', 'pad_to_multiple_of', 'label_pad_token_id', 'label_to_id',
#        'max_span_length', 'wiki_to_vec_file', 'gazetteer_path',
#        'gazetteer_add_input_tokens', 'gazetteer_add_output_features',
#        'model_target', 'model_name_or_path', 'learning_rate',
#        'task_learning_rate', 'warmup_proportion', 'ignore_index',
#        'span_length_embedding_dim', 'freeze_model', 'layer_mean',
#        'augment_input', 'augment_input_prob', 'use_mlp', 'mlp_hidden_dim',
#        'mlp_num_layers', 'dropout_prob', 'use_language_model',
#        'use_span_length_embedding'],
#       dtype='object')

# %%
df.sort_values(by="val/f1", ascending=False)[:50][["id", "val/f1", "train/f1", "batch_size", "learning_rate", "task_learning_rate", "wiki_to_vec_file", "gazetteer_add_output_features", "gazetteer_add_input_tokens", "gazetteer_path", "augment_input", "augment_input_prob", "use_mlp", "mlp_hidden_dim", "mlp_num_layers", "model_name_or_path"]]
# Out:
#            id    val/f1  train/f1  batch_size  learning_rate  \
# 77   189dh04u  0.910423  0.945358          16       0.000010
# 8    tkoj95qs  0.909843  0.892003          16       0.000010
# 123  30h3uizb  0.899585  0.988594          32       0.000010
# 121  10cd4j62  0.896945  0.985201          32       0.000010
# 26   34bizri5  0.891947  0.974973          32       0.000010
# 19   16mclf9r  0.891033  0.924516          32       0.000050
# 20   1yfizu0u  0.890631  0.971660          32       0.000010
# 35   2iwqh41v  0.889072  0.981810          32       0.000050
# 14   3ktl34lz  0.888166  0.963562          32       0.000010
# 27   1nwj2ove  0.886831  0.855188          32       0.000010
# 45   wtnsnols  0.880232  0.843533          32       0.000010
# 118  3krpp4o3  0.879484  0.970487          32       0.000010
# 18   1r26cmz0  0.873362  0.971324          32       0.000050
# 119  2jrs3n6g  0.871417  0.984759          32       0.000010
# 89   y94w2aik  0.871009  0.889114          32       0.000030
# 50   1d3m9qnz  0.853933  0.890685          16       0.000032
# 28   vx8lf2w2  0.850652  0.895497          32       0.000010
# 60   2gkhd1tl  0.835871  0.864967          16       0.000033
# 70   3699dtwr  0.684337  0.726031          32       0.000083
# 7    2tkbf0t7  0.676343  0.697023           8       0.000100
# 74   2tw8n17c  0.675238  0.680318          16       0.000031
# 54   1vnj45iv  0.673152  0.700680          32       0.000014
# 6    i39wwdzc  0.668645  0.693990           8       0.000050
# 48   3jtpy5hh  0.667324  0.692249          32       0.000045
# 57   3kmkglwp  0.664659  0.735748          32       0.000025
# 80   3ad0do62  0.664036  0.703996          16       0.000010
# 63   xz8bzijt  0.664028  0.742810          16       0.000049
# 85   2xt997wl  0.664020  0.703873          16       0.000050
# 52   2p8sfyt8  0.662716  0.701959          16       0.000052
# 81   21ymy6pl  0.662698  0.703107          16       0.000010
# 59   3gwjpchu  0.662049  0.696577          32       0.000076
# 84   1s11akcf  0.660732  0.747222          16       0.000050
# 78   2grudinm  0.660040  0.693803          16       0.000050
# 79   3mz9cpks  0.659373  0.693226          16       0.000050
# 5    3w4nacko  0.658039  0.688135           8       0.000010
# 10   211od120  0.656672  0.675911          16       0.000100
# 55   3chg60sn  0.656048  0.702019          16       0.000067
# 38   1bzr29sb  0.655802  0.655745          32       0.000050
# 82   1nec0ln7  0.655672  0.719782          16       0.000030
# 104  3926lmpx  0.655555  0.736266          32       0.000050
# 88   11z12asf  0.654726  0.690984          16       0.000030
# 49   1m8ou9gy  0.654691  0.694038          16       0.000012
# 61   3utueic8  0.654057  0.703004          16       0.000041
# 111  2peh20to  0.653712  0.712580          16       0.000030
# 107  2gnfe1ac  0.652938  0.692515          16       0.000050
# 100  q9pjprzh  0.652525  0.718586          32       0.000010
# 56   rmt2s7k1  0.651978  0.714790          16       0.000058
# 69   3ne9vz94  0.651662  0.716866          32       0.000066
# 62   2naphsvn  0.651606  0.704924          16       0.000021
# 39   3th4m8vd  0.651530  0.654757          32       0.000050
#
#      task_learning_rate                                   wiki_to_vec_file  \
# 77             0.000050  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 8              0.000100  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 123            0.000050  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 121            0.000050  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 26             0.000100  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 19             0.000010  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 20             0.000010  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 35             0.000100  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 14             0.000010  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 27             0.000100  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 45             0.000010  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 118            0.000050                                               None
# 18             0.000010  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 119            0.000050                                               None
# 89             0.000050  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 50             0.000250  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 28             0.000100  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 60             0.000203  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 70             0.000466  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 7              0.000100  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 74             0.000196  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 54             0.000283  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 6              0.000100  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 48             0.000329  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 57             0.000326  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 80             0.000300  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 63             0.000255  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 85             0.000300  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 52             0.000428  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 81             0.000300  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 59             0.000490  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 84             0.000300  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 78             0.000100  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 79             0.000100  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 5              0.000100  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 10             0.000100  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 55             0.000405  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 38             0.000100  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 82             0.000300  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 104            0.000300  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 88             0.000050  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 49             0.000171  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 61             0.000203  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 111            0.000100  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 107            0.000050  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 100            0.000300  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 56             0.000256  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 69             0.000455  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 62             0.000132  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 39             0.000100  /vol/home-vol2/ml/altchris/projects/multi-cone...
#
#      gazetteer_add_output_features  gazetteer_add_input_tokens  \
# 77                            True                        True
# 8                             True                        True
# 123                          False                       False
# 121                          False                       False
# 26                           False                       False
# 19                            True                       False
# 20                            True                       False
# 35                           False                       False
# 14                           False                       False
# 27                           False                       False
# 45                            True                        True
# 118                          False                       False
# 18                            True                       False
# 119                          False                       False
# 89                            True                        True
# 50                            True                        True
# 28                            True                       False
# 60                            True                        True
# 70                            True                        True
# 7                             True                        True
# 74                            True                        True
# 54                            True                        True
# 6                             True                        True
# 48                            True                        True
# 57                            True                        True
# 80                            True                        True
# 63                            True                        True
# 85                            True                        True
# 52                            True                        True
# 81                            True                        True
# 59                            True                        True
# 84                            True                        True
# 78                            True                        True
# 79                            True                        True
# 5                             True                        True
# 10                            True                        True
# 55                            True                        True
# 38                            True                       False
# 82                            True                        True
# 104                           True                        True
# 88                            True                        True
# 49                            True                        True
# 61                            True                        True
# 111                           True                        True
# 107                           True                        True
# 100                           True                        True
# 56                            True                        True
# 69                            True                        True
# 62                            True                        True
# 39                            True                       False
#
#                                         gazetteer_path  augment_input  \
# 77   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 8    /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 123                                               None          False
# 121                                               None          False
# 26   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 19   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 20   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 35   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 14   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 27   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 45   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 118                                               None          False
# 18   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 119                                               None          False
# 89   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 50   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 28   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 60   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 70   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 7    /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 74   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 54   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 6    /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 48   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 57   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 80   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 63   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 85   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 52   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 81   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 59   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 84   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 78   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 79   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 5    /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 10   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 55   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 38   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 82   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 104  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 88   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 49   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 61   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 111  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 107  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 100  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 56   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 69   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 62   /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 39   /vol/home-vol2/ml/altchris/projects/multi-cone...           True
#
#      augment_input_prob  use_mlp  mlp_hidden_dim  mlp_num_layers  \
# 77             0.300000     True            1024               2
# 8              0.200000     True            1024               2
# 123            0.200000     True            1024               2
# 121            0.200000     True            1024               2
# 26             0.200000     True            1024               2
# 19             0.200000     True            1024               2
# 20             0.200000     True            1024               2
# 35             0.200000     True            1024               2
# 14             0.200000     True            1024               2
# 27             0.200000     True            1024               2
# 45             0.200000     True            1024               2
# 118            0.200000     True            1024               2
# 18             0.200000     True            1024               2
# 119            0.200000     True            1024               2
# 89             0.200000     True            1024               2
# 50             0.323977     True             128               2
# 28             0.200000     True            1024               2
# 60             0.142144     True             512               2
# 70             0.230234     True            1024               2
# 7              0.200000     True            1024               2
# 74             0.138387     True             512               2
# 54             0.211416     True            1024               2
# 6              0.200000     True            1024               2
# 48             0.261817     True             128               2
# 57             0.226294     True            1024               2
# 80             0.200000     True            1024               2
# 63             0.126006     True            1024               2
# 85             0.300000     True            1024               2
# 52             0.324056     True             128               2
# 81             0.300000     True            1024               2
# 59             0.303388     True             128               2
# 84             0.200000     True            1024               2
# 78             0.200000     True            1024               2
# 79             0.300000     True            1024               2
# 5              0.200000     True            1024               2
# 10             0.200000     True            1024               2
# 55             0.351576     True             128               2
# 38             0.200000     True            1024               2
# 82             0.200000     True            1024               2
# 104            0.200000     True            1024               2
# 88             0.200000     True            1024               2
# 49             0.226998     True             512               2
# 61             0.175424     True             512               2
# 111            0.300000     True            1024               2
# 107            0.300000     True            1024               2
# 100            0.200000     True            1024               2
# 56             0.263506     True            1024               2
# 69             0.485859     True             256               2
# 62             0.186278     True             512               2
# 39             0.200000     True            1024               2
#
#                      model_name_or_path
# 77   google/electra-large-discriminator
# 8    google/electra-large-discriminator
# 123  google/electra-large-discriminator
# 121  google/electra-large-discriminator
# 26   google/electra-large-discriminator
# 19   google/electra-large-discriminator
# 20   google/electra-large-discriminator
# 35   google/electra-large-discriminator
# 14   google/electra-large-discriminator
# 27   google/electra-large-discriminator
# 45   google/electra-large-discriminator
# 118  google/electra-large-discriminator
# 18   google/electra-large-discriminator
# 119  google/electra-large-discriminator
# 89   google/electra-large-discriminator
# 50   google/electra-large-discriminator
# 28   google/electra-large-discriminator
# 60   google/electra-large-discriminator
# 70   google/electra-large-discriminator
# 7    google/electra-large-discriminator
# 74   google/electra-large-discriminator
# 54   google/electra-large-discriminator
# 6    google/electra-large-discriminator
# 48   google/electra-large-discriminator
# 57   google/electra-large-discriminator
# 80   google/electra-large-discriminator
# 63   google/electra-large-discriminator
# 85   google/electra-large-discriminator
# 52   google/electra-large-discriminator
# 81   google/electra-large-discriminator
# 59   google/electra-large-discriminator
# 84   google/electra-large-discriminator
# 78   google/electra-large-discriminator
# 79   google/electra-large-discriminator
# 5    google/electra-large-discriminator
# 10   google/electra-large-discriminator
# 55   google/electra-large-discriminator
# 38   google/electra-large-discriminator
# 82   google/electra-large-discriminator
# 104  google/electra-large-discriminator
# 88   google/electra-large-discriminator
# 49   google/electra-large-discriminator
# 61   google/electra-large-discriminator
# 111  google/electra-large-discriminator
# 107  google/electra-large-discriminator
# 100  google/electra-large-discriminator
# 56   google/electra-large-discriminator
# 69   google/electra-large-discriminator
# 62   google/electra-large-discriminator
# 39   google/electra-large-discriminator

# %%
df.columns
# Out:
# Index(['train/loss_step', 'epoch', 'trainer/global_step', 'val/loss', 'val/f1',
#        'train/loss_epoch', 'train/f1', 'batch_size', 'datamodule_target',
#        'data_dir', 'name', 'num_workers', 'pin_memory', 'taskmodule_target',
#        'tokenizer_name_or_path', 'entity_annotation', 'padding', 'truncation',
#        'max_length', 'pad_to_multiple_of', 'label_pad_token_id', 'label_to_id',
#        'max_span_length', 'wiki_to_vec_file', 'gazetteer_path',
#        'gazetteer_add_input_tokens', 'gazetteer_add_output_features',
#        'model_target', 'model_name_or_path', 'learning_rate',
#        'task_learning_rate', 'warmup_proportion', 'ignore_index',
#        'span_length_embedding_dim', 'freeze_model', 'layer_mean',
#        'augment_input', 'augment_input_prob', 'use_mlp', 'mlp_hidden_dim',
#        'mlp_num_layers'],
#       dtype='object')
