# %%
# %load_ext autoreload
# %autoreload 2

import sys

sys.path.append("../")

# %%
RUNS_PATH = "/media/christoph/HDD/experiments/multi_coner_remote/multiruns/"

# %%
import json
import wandb

from pathlib import Path
from omegaconf import OmegaConf
from itertools import chain

# %%
def runs_as_dicts(path: str):
    path = Path(path)
    
    run_directories = [p.parent for p in path.glob("**/config_tree.txt")]
    
    run_dicts = []
    for directory in run_directories:
        hydra_directory = directory / ".hydra"
        wandb_directory = directory / "wandb"
        
        hydra_config_file = hydra_directory / "config.yaml"
        
        assert hydra_config_file.exists()
        
        wandb_run_directories = list(wandb_directory.glob("run-*"))
        
        if len(wandb_run_directories) != 1:
            print("No wandb run directory found in ", directory)
            continue
        
        wandb_run_directory = wandb_run_directories[0]
        
        wandb_run_id = wandb_run_directory.name.split("-")[-1]
        
        wandb_files_directory = wandb_run_directory / "files"
        
        wandb_metadata_file = wandb_files_directory / "wandb-metadata.json"
        wandb_summary_file = wandb_files_directory / "wandb-summary.json"
        
        assert wandb_metadata_file.exists()
        assert wandb_summary_file.exists()
        
        validation_file = directory / "checkpoints" / "validation_result.json"
        augmented_validation_file = directory / "checkpoints" / "augm_validation_result.json"
        
        assert validation_file.exists()
        assert augmented_validation_file.exists()
        
        hydra_config = OmegaConf.load(hydra_config_file)
        
        with wandb_metadata_file.open() as f:
            wandb_metadata = json.load(f)
        
        with wandb_summary_file.open() as f:
            wandb_summary = json.load(f)
        
        with validation_file.open() as f:
            validation_result = json.load(f)
        
        with augmented_validation_file.open() as f:
            augmented_validation_result = json.load(f)
        
        run_dict = {
            "wandb": {
                "id": wandb_run_id,
                "metadata": wandb_metadata,
                "summary": wandb_summary,
            },
            "hydra": OmegaConf.to_container(hydra_config, resolve=False),
            "validation": {
                "original": validation_result,
                "augmented": augmented_validation_result,
            }
        }
        
        run_dicts.append(run_dict)
    
    return run_dicts

# %%
run_dicts = runs_as_dicts(RUNS_PATH)
# Out:
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/29
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/10
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/11
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/12
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/13
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/14
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/15
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/24
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/25
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/26
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/27
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/28
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/30
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/31
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/40
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/41
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/42
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/43
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/44
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/45
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/46
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/47
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/56
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/57
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/58
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/59
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/60
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/61
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/62
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/63
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/8
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-10_20-35-49/9
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-11_00-06-08/0
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-11_00-07-35/0
# No wandb run directory found in  /media/christoph/HDD/experiments/multi_coner_remote/multiruns/2022-02-14_14-10-47/0

# %%
import pandas as pd

# %%
def run_dicts_to_dataframe(run_dicts):
    table = []
    for run_dict in run_dicts:
        table_row = {"id": run_dict["wandb"]["id"]}
        
        validation_metrics = [(f"val/orig/{key}", value) for key, value in run_dict["validation"]["original"]["macro avg"].items()]
        
        table_row.update(validation_metrics)
        
        augmented_validation_metrics = [(f"val/augm/{key}", value) for key, value in run_dict["validation"]["augmented"]["macro avg"].items()]
    
        table_row.update(augmented_validation_metrics)
        
        wandb_metrics = [(metric, val) for metric, val in run_dict["wandb"]["summary"].items() if not metric.startswith("_")]

        table_row.update(wandb_metrics)
    
        hydra_config = run_dict["hydra"]
    
        table_row["batch_size"] = hydra_config["datamodule"]["batch_size"]
        
        hydra_metrics = [(f"{config_key}_target", val) if key == "_target_" else (key, val) for config_key in ["datamodule", "taskmodule", "model"] for key, val in hydra_config[config_key].items()]
    
        table_row.update(hydra_metrics)
    
        table.append(table_row)
    
    df = pd.DataFrame(table)
    
    df = df.set_index("id")
    
    return df

# %%
df = run_dicts_to_dataframe(run_dicts)

# %%
df.sort_values(by="val/f1", ascending=False)[:50][[
    "val/f1", "val/orig/f1-score", "val/augm/f1-score", "train/f1", "batch_size", "learning_rate", "task_learning_rate", "wiki_to_vec_file",
    "gazetteer_add_output_features", "gazetteer_add_input_tokens", "gazetteer_path", "augment_input", "augment_input_prob", "use_mlp",
    "mlp_hidden_dim", "mlp_num_layers", "model_name_or_path", "use_span_length_embedding", "use_language_model"]]
# Out:
#             val/f1  val/orig/f1-score  val/augm/f1-score  train/f1  \
# id
# 189dh04u  0.910423           0.903801           0.892559  0.945358
# tkoj95qs  0.909843           0.900480           0.884286  0.892003
# 30h3uizb  0.899585           0.888922           0.833542  0.988594
# 10cd4j62  0.896945           0.890265           0.833772  0.985201
# 34bizri5  0.891947           0.885088           0.829004  0.974973
# 16mclf9r  0.891033           0.886239           0.840657  0.924516
# 1yfizu0u  0.890631           0.881313           0.827188  0.971660
# 2iwqh41v  0.889072           0.879458           0.842795  0.981810
# 3ktl34lz  0.888166           0.874650           0.817828  0.963562
# 1nwj2ove  0.886831           0.876612           0.835322  0.855188
# wtnsnols  0.880232           0.866294           0.834513  0.843533
# 3krpp4o3  0.879484           0.872284           0.814090  0.970487
# 1r26cmz0  0.873362           0.876278           0.827763  0.971324
# 2jrs3n6g  0.871417           0.869005           0.819450  0.984759
# y94w2aik  0.871009           0.851505           0.845741  0.889114
# 1d3m9qnz  0.853933           0.836152           0.835803  0.890685
# vx8lf2w2  0.850652           0.831026           0.791935  0.895497
# 2gkhd1tl  0.835871           0.820413           0.832822  0.864967
# 3699dtwr  0.684337           0.689822           0.705209  0.726031
# 2tkbf0t7  0.676343           0.654950           0.665195  0.697023
# 2tw8n17c  0.675238           0.812931           0.813672  0.680318
# 1vnj45iv  0.673152           0.661857           0.672734  0.700680
# i39wwdzc  0.668645           0.642364           0.650893  0.693990
# 3jtpy5hh  0.667324           0.647811           0.658543  0.692249
# 3kmkglwp  0.664659           0.656082           0.665190  0.735748
# 3ad0do62  0.664036           0.657154           0.669851  0.703996
# xz8bzijt  0.664028           0.654207           0.665748  0.742810
# 2xt997wl  0.664020           0.646156           0.658671  0.703873
# 2p8sfyt8  0.662716           0.644006           0.654258  0.701959
# 21ymy6pl  0.662698           0.659465           0.673721  0.703107
# 3gwjpchu  0.662049           0.653313           0.662791  0.696577
# 1s11akcf  0.660732           0.663728           0.674601  0.747222
# 2grudinm  0.660040           0.632746           0.640847  0.693803
# 3mz9cpks  0.659373           0.632332           0.640868  0.693226
# 3w4nacko  0.658039           0.631443           0.639458  0.688135
# 211od120  0.656672           0.631114           0.638980  0.675911
# 3chg60sn  0.656048           0.656188           0.666941  0.702019
# 1bzr29sb  0.655802           0.638478           0.649794  0.655745
# 1nec0ln7  0.655672           0.633585           0.639486  0.719782
# 3926lmpx  0.655555           0.642418           0.649290  0.736266
# 11z12asf  0.654726           0.632991           0.642354  0.690984
# 1m8ou9gy  0.654691           0.628120           0.635876  0.694038
# 3utueic8  0.654057           0.634034           0.641427  0.703004
# 2peh20to  0.653712           0.632739           0.641071  0.712580
# 2gnfe1ac  0.652938           0.618658           0.626446  0.692515
# q9pjprzh  0.652525           0.648896           0.659668  0.718586
# rmt2s7k1  0.651978           0.653664           0.667456  0.714790
# 3ne9vz94  0.651662           0.645051           0.654718  0.716866
# 2naphsvn  0.651606           0.638499           0.647047  0.704924
# 3th4m8vd  0.651530           0.624491           0.632541  0.654757
#
#           batch_size  learning_rate  task_learning_rate  \
# id
# 189dh04u          16       0.000010            0.000050
# tkoj95qs          16       0.000010            0.000100
# 30h3uizb          32       0.000010            0.000050
# 10cd4j62          32       0.000010            0.000050
# 34bizri5          32       0.000010            0.000100
# 16mclf9r          32       0.000050            0.000010
# 1yfizu0u          32       0.000010            0.000010
# 2iwqh41v          32       0.000050            0.000100
# 3ktl34lz          32       0.000010            0.000010
# 1nwj2ove          32       0.000010            0.000100
# wtnsnols          32       0.000010            0.000010
# 3krpp4o3          32       0.000010            0.000050
# 1r26cmz0          32       0.000050            0.000010
# 2jrs3n6g          32       0.000010            0.000050
# y94w2aik          32       0.000030            0.000050
# 1d3m9qnz          16       0.000032            0.000250
# vx8lf2w2          32       0.000010            0.000100
# 2gkhd1tl          16       0.000033            0.000203
# 3699dtwr          32       0.000083            0.000466
# 2tkbf0t7           8       0.000100            0.000100
# 2tw8n17c          16       0.000031            0.000196
# 1vnj45iv          32       0.000014            0.000283
# i39wwdzc           8       0.000050            0.000100
# 3jtpy5hh          32       0.000045            0.000329
# 3kmkglwp          32       0.000025            0.000326
# 3ad0do62          16       0.000010            0.000300
# xz8bzijt          16       0.000049            0.000255
# 2xt997wl          16       0.000050            0.000300
# 2p8sfyt8          16       0.000052            0.000428
# 21ymy6pl          16       0.000010            0.000300
# 3gwjpchu          32       0.000076            0.000490
# 1s11akcf          16       0.000050            0.000300
# 2grudinm          16       0.000050            0.000100
# 3mz9cpks          16       0.000050            0.000100
# 3w4nacko           8       0.000010            0.000100
# 211od120          16       0.000100            0.000100
# 3chg60sn          16       0.000067            0.000405
# 1bzr29sb          32       0.000050            0.000100
# 1nec0ln7          16       0.000030            0.000300
# 3926lmpx          32       0.000050            0.000300
# 11z12asf          16       0.000030            0.000050
# 1m8ou9gy          16       0.000012            0.000171
# 3utueic8          16       0.000041            0.000203
# 2peh20to          16       0.000030            0.000100
# 2gnfe1ac          16       0.000050            0.000050
# q9pjprzh          32       0.000010            0.000300
# rmt2s7k1          16       0.000058            0.000256
# 3ne9vz94          32       0.000066            0.000455
# 2naphsvn          16       0.000021            0.000132
# 3th4m8vd          32       0.000050            0.000100
#
#                                            wiki_to_vec_file  \
# id
# 189dh04u  /vol/home-vol2/ml/altchris/projects/multi-cone...
# tkoj95qs  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 30h3uizb  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 10cd4j62  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 34bizri5  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 16mclf9r  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 1yfizu0u  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2iwqh41v  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3ktl34lz  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 1nwj2ove  /vol/home-vol2/ml/altchris/projects/multi-cone...
# wtnsnols  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3krpp4o3                                               None
# 1r26cmz0  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2jrs3n6g                                               None
# y94w2aik  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 1d3m9qnz  /vol/home-vol2/ml/altchris/projects/multi-cone...
# vx8lf2w2  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2gkhd1tl  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3699dtwr  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2tkbf0t7  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2tw8n17c  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 1vnj45iv  /vol/home-vol2/ml/altchris/projects/multi-cone...
# i39wwdzc  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3jtpy5hh  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3kmkglwp  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3ad0do62  /vol/home-vol2/ml/altchris/projects/multi-cone...
# xz8bzijt  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2xt997wl  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2p8sfyt8  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 21ymy6pl  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3gwjpchu  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 1s11akcf  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2grudinm  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3mz9cpks  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3w4nacko  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 211od120  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3chg60sn  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 1bzr29sb  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 1nec0ln7  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3926lmpx  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 11z12asf  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 1m8ou9gy  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3utueic8  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2peh20to  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2gnfe1ac  /vol/home-vol2/ml/altchris/projects/multi-cone...
# q9pjprzh  /vol/home-vol2/ml/altchris/projects/multi-cone...
# rmt2s7k1  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3ne9vz94  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2naphsvn  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3th4m8vd  /vol/home-vol2/ml/altchris/projects/multi-cone...
#
#           gazetteer_add_output_features  gazetteer_add_input_tokens  \
# id
# 189dh04u                           True                        True
# tkoj95qs                           True                        True
# 30h3uizb                          False                       False
# 10cd4j62                          False                       False
# 34bizri5                          False                       False
# 16mclf9r                           True                       False
# 1yfizu0u                           True                       False
# 2iwqh41v                          False                       False
# 3ktl34lz                          False                       False
# 1nwj2ove                          False                       False
# wtnsnols                           True                        True
# 3krpp4o3                          False                       False
# 1r26cmz0                           True                       False
# 2jrs3n6g                          False                       False
# y94w2aik                           True                        True
# 1d3m9qnz                           True                        True
# vx8lf2w2                           True                       False
# 2gkhd1tl                           True                        True
# 3699dtwr                           True                        True
# 2tkbf0t7                           True                        True
# 2tw8n17c                           True                        True
# 1vnj45iv                           True                        True
# i39wwdzc                           True                        True
# 3jtpy5hh                           True                        True
# 3kmkglwp                           True                        True
# 3ad0do62                           True                        True
# xz8bzijt                           True                        True
# 2xt997wl                           True                        True
# 2p8sfyt8                           True                        True
# 21ymy6pl                           True                        True
# 3gwjpchu                           True                        True
# 1s11akcf                           True                        True
# 2grudinm                           True                        True
# 3mz9cpks                           True                        True
# 3w4nacko                           True                        True
# 211od120                           True                        True
# 3chg60sn                           True                        True
# 1bzr29sb                           True                       False
# 1nec0ln7                           True                        True
# 3926lmpx                           True                        True
# 11z12asf                           True                        True
# 1m8ou9gy                           True                        True
# 3utueic8                           True                        True
# 2peh20to                           True                        True
# 2gnfe1ac                           True                        True
# q9pjprzh                           True                        True
# rmt2s7k1                           True                        True
# 3ne9vz94                           True                        True
# 2naphsvn                           True                        True
# 3th4m8vd                           True                       False
#
#                                              gazetteer_path  augment_input  \
# id
# 189dh04u  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# tkoj95qs  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 30h3uizb                                               None          False
# 10cd4j62                                               None          False
# 34bizri5  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 16mclf9r  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 1yfizu0u  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 2iwqh41v  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 3ktl34lz  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 1nwj2ove  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# wtnsnols  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 3krpp4o3                                               None          False
# 1r26cmz0  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 2jrs3n6g                                               None          False
# y94w2aik  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 1d3m9qnz  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# vx8lf2w2  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 2gkhd1tl  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 3699dtwr  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 2tkbf0t7  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 2tw8n17c  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 1vnj45iv  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# i39wwdzc  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 3jtpy5hh  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 3kmkglwp  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 3ad0do62  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# xz8bzijt  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 2xt997wl  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 2p8sfyt8  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 21ymy6pl  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 3gwjpchu  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 1s11akcf  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 2grudinm  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 3mz9cpks  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 3w4nacko  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 211od120  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 3chg60sn  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 1bzr29sb  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 1nec0ln7  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 3926lmpx  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 11z12asf  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 1m8ou9gy  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 3utueic8  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 2peh20to  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 2gnfe1ac  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# q9pjprzh  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# rmt2s7k1  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 3ne9vz94  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 2naphsvn  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 3th4m8vd  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
#
#           augment_input_prob  use_mlp  mlp_hidden_dim  mlp_num_layers  \
# id
# 189dh04u            0.300000     True            1024               2
# tkoj95qs            0.200000     True            1024               2
# 30h3uizb            0.200000     True            1024               2
# 10cd4j62            0.200000     True            1024               2
# 34bizri5            0.200000     True            1024               2
# 16mclf9r            0.200000     True            1024               2
# 1yfizu0u            0.200000     True            1024               2
# 2iwqh41v            0.200000     True            1024               2
# 3ktl34lz            0.200000     True            1024               2
# 1nwj2ove            0.200000     True            1024               2
# wtnsnols            0.200000     True            1024               2
# 3krpp4o3            0.200000     True            1024               2
# 1r26cmz0            0.200000     True            1024               2
# 2jrs3n6g            0.200000     True            1024               2
# y94w2aik            0.200000     True            1024               2
# 1d3m9qnz            0.323977     True             128               2
# vx8lf2w2            0.200000     True            1024               2
# 2gkhd1tl            0.142144     True             512               2
# 3699dtwr            0.230234     True            1024               2
# 2tkbf0t7            0.200000     True            1024               2
# 2tw8n17c            0.138387     True             512               2
# 1vnj45iv            0.211416     True            1024               2
# i39wwdzc            0.200000     True            1024               2
# 3jtpy5hh            0.261817     True             128               2
# 3kmkglwp            0.226294     True            1024               2
# 3ad0do62            0.200000     True            1024               2
# xz8bzijt            0.126006     True            1024               2
# 2xt997wl            0.300000     True            1024               2
# 2p8sfyt8            0.324056     True             128               2
# 21ymy6pl            0.300000     True            1024               2
# 3gwjpchu            0.303388     True             128               2
# 1s11akcf            0.200000     True            1024               2
# 2grudinm            0.200000     True            1024               2
# 3mz9cpks            0.300000     True            1024               2
# 3w4nacko            0.200000     True            1024               2
# 211od120            0.200000     True            1024               2
# 3chg60sn            0.351576     True             128               2
# 1bzr29sb            0.200000     True            1024               2
# 1nec0ln7            0.200000     True            1024               2
# 3926lmpx            0.200000     True            1024               2
# 11z12asf            0.200000     True            1024               2
# 1m8ou9gy            0.226998     True             512               2
# 3utueic8            0.175424     True             512               2
# 2peh20to            0.300000     True            1024               2
# 2gnfe1ac            0.300000     True            1024               2
# q9pjprzh            0.200000     True            1024               2
# rmt2s7k1            0.263506     True            1024               2
# 3ne9vz94            0.485859     True             256               2
# 2naphsvn            0.186278     True             512               2
# 3th4m8vd            0.200000     True            1024               2
#
#                           model_name_or_path use_span_length_embedding  \
# id
# 189dh04u  google/electra-large-discriminator                       NaN
# tkoj95qs  google/electra-large-discriminator                       NaN
# 30h3uizb  google/electra-large-discriminator                      True
# 10cd4j62  google/electra-large-discriminator                      True
# 34bizri5  google/electra-large-discriminator                       NaN
# 16mclf9r  google/electra-large-discriminator                       NaN
# 1yfizu0u  google/electra-large-discriminator                       NaN
# 2iwqh41v  google/electra-large-discriminator                       NaN
# 3ktl34lz  google/electra-large-discriminator                       NaN
# 1nwj2ove  google/electra-large-discriminator                       NaN
# wtnsnols  google/electra-large-discriminator                       NaN
# 3krpp4o3  google/electra-large-discriminator                      True
# 1r26cmz0  google/electra-large-discriminator                       NaN
# 2jrs3n6g  google/electra-large-discriminator                      True
# y94w2aik  google/electra-large-discriminator                       NaN
# 1d3m9qnz  google/electra-large-discriminator                       NaN
# vx8lf2w2  google/electra-large-discriminator                       NaN
# 2gkhd1tl  google/electra-large-discriminator                       NaN
# 3699dtwr  google/electra-large-discriminator                       NaN
# 2tkbf0t7  google/electra-large-discriminator                       NaN
# 2tw8n17c  google/electra-large-discriminator                       NaN
# 1vnj45iv  google/electra-large-discriminator                       NaN
# i39wwdzc  google/electra-large-discriminator                       NaN
# 3jtpy5hh  google/electra-large-discriminator                       NaN
# 3kmkglwp  google/electra-large-discriminator                       NaN
# 3ad0do62  google/electra-large-discriminator                       NaN
# xz8bzijt  google/electra-large-discriminator                       NaN
# 2xt997wl  google/electra-large-discriminator                       NaN
# 2p8sfyt8  google/electra-large-discriminator                       NaN
# 21ymy6pl  google/electra-large-discriminator                       NaN
# 3gwjpchu  google/electra-large-discriminator                       NaN
# 1s11akcf  google/electra-large-discriminator                       NaN
# 2grudinm  google/electra-large-discriminator                       NaN
# 3mz9cpks  google/electra-large-discriminator                       NaN
# 3w4nacko  google/electra-large-discriminator                       NaN
# 211od120  google/electra-large-discriminator                       NaN
# 3chg60sn  google/electra-large-discriminator                       NaN
# 1bzr29sb  google/electra-large-discriminator                       NaN
# 1nec0ln7  google/electra-large-discriminator                       NaN
# 3926lmpx  google/electra-large-discriminator                       NaN
# 11z12asf  google/electra-large-discriminator                       NaN
# 1m8ou9gy  google/electra-large-discriminator                       NaN
# 3utueic8  google/electra-large-discriminator                       NaN
# 2peh20to  google/electra-large-discriminator                       NaN
# 2gnfe1ac  google/electra-large-discriminator                       NaN
# q9pjprzh  google/electra-large-discriminator                       NaN
# rmt2s7k1  google/electra-large-discriminator                       NaN
# 3ne9vz94  google/electra-large-discriminator                       NaN
# 2naphsvn  google/electra-large-discriminator                       NaN
# 3th4m8vd  google/electra-large-discriminator                       NaN
#
#          use_language_model
# id
# 189dh04u                NaN
# tkoj95qs                NaN
# 30h3uizb               True
# 10cd4j62               True
# 34bizri5                NaN
# 16mclf9r                NaN
# 1yfizu0u                NaN
# 2iwqh41v                NaN
# 3ktl34lz                NaN
# 1nwj2ove                NaN
# wtnsnols                NaN
# 3krpp4o3               True
# 1r26cmz0                NaN
# 2jrs3n6g               True
# y94w2aik                NaN
# 1d3m9qnz                NaN
# vx8lf2w2                NaN
# 2gkhd1tl                NaN
# 3699dtwr                NaN
# 2tkbf0t7                NaN
# 2tw8n17c                NaN
# 1vnj45iv                NaN
# i39wwdzc                NaN
# 3jtpy5hh                NaN
# 3kmkglwp                NaN
# 3ad0do62                NaN
# xz8bzijt                NaN
# 2xt997wl                NaN
# 2p8sfyt8                NaN
# 21ymy6pl                NaN
# 3gwjpchu                NaN
# 1s11akcf                NaN
# 2grudinm                NaN
# 3mz9cpks                NaN
# 3w4nacko                NaN
# 211od120                NaN
# 3chg60sn                NaN
# 1bzr29sb                NaN
# 1nec0ln7                NaN
# 3926lmpx                NaN
# 11z12asf                NaN
# 1m8ou9gy                NaN
# 3utueic8                NaN
# 2peh20to                NaN
# 2gnfe1ac                NaN
# q9pjprzh                NaN
# rmt2s7k1                NaN
# 3ne9vz94                NaN
# 2naphsvn                NaN
# 3th4m8vd                NaN

# %%
df.columns
# Out:
# Index(['id', 'val/orig/f1-score', 'val/orig/precision', 'val/orig/recall',
#        'val/orig/support', 'val/augm/f1-score', 'val/augm/precision',
#        'val/augm/recall', 'val/augm/support', 'train/loss_step', 'epoch',
#        'trainer/global_step', 'val/loss', 'val/f1', 'train/loss_epoch',
#        'train/f1', 'batch_size', 'datamodule_target', 'data_dir', 'name',
#        'num_workers', 'pin_memory', 'taskmodule_target',
#        'tokenizer_name_or_path', 'entity_annotation', 'padding', 'truncation',
#        'max_length', 'pad_to_multiple_of', 'label_pad_token_id', 'label_to_id',
#        'max_span_length', 'wiki_to_vec_file', 'gazetteer_path',
#        'gazetteer_add_input_tokens', 'gazetteer_add_output_features',
#        'model_target', 'model_name_or_path', 'learning_rate',
#        'task_learning_rate', 'warmup_proportion', 'ignore_index',
#        'span_length_embedding_dim', 'freeze_model', 'layer_mean',
#        'augment_input', 'augment_input_prob', 'use_mlp', 'mlp_hidden_dim',
#        'mlp_num_layers', 'dropout_prob', 'use_language_model',
#        'use_span_length_embedding'],
#       dtype='object')

# %%
df.sort_values(by="val/f1", ascending=False)[:50][["val/f1", "train/f1", "batch_size", "learning_rate", "task_learning_rate", "wiki_to_vec_file", "gazetteer_add_output_features", "gazetteer_add_input_tokens", "gazetteer_path", "augment_input", "augment_input_prob", "use_mlp", "mlp_hidden_dim", "mlp_num_layers", "model_name_or_path"]]
# Out:
#             val/f1  train/f1  batch_size  learning_rate  task_learning_rate  \
# id
# 189dh04u  0.910423  0.945358          16       0.000010            0.000050
# tkoj95qs  0.909843  0.892003          16       0.000010            0.000100
# 30h3uizb  0.899585  0.988594          32       0.000010            0.000050
# 10cd4j62  0.896945  0.985201          32       0.000010            0.000050
# 34bizri5  0.891947  0.974973          32       0.000010            0.000100
# 16mclf9r  0.891033  0.924516          32       0.000050            0.000010
# 1yfizu0u  0.890631  0.971660          32       0.000010            0.000010
# 2iwqh41v  0.889072  0.981810          32       0.000050            0.000100
# 3ktl34lz  0.888166  0.963562          32       0.000010            0.000010
# 1nwj2ove  0.886831  0.855188          32       0.000010            0.000100
# wtnsnols  0.880232  0.843533          32       0.000010            0.000010
# 3krpp4o3  0.879484  0.970487          32       0.000010            0.000050
# 1r26cmz0  0.873362  0.971324          32       0.000050            0.000010
# 2jrs3n6g  0.871417  0.984759          32       0.000010            0.000050
# y94w2aik  0.871009  0.889114          32       0.000030            0.000050
# 1d3m9qnz  0.853933  0.890685          16       0.000032            0.000250
# vx8lf2w2  0.850652  0.895497          32       0.000010            0.000100
# 2gkhd1tl  0.835871  0.864967          16       0.000033            0.000203
# 3699dtwr  0.684337  0.726031          32       0.000083            0.000466
# 2tkbf0t7  0.676343  0.697023           8       0.000100            0.000100
# 2tw8n17c  0.675238  0.680318          16       0.000031            0.000196
# 1vnj45iv  0.673152  0.700680          32       0.000014            0.000283
# i39wwdzc  0.668645  0.693990           8       0.000050            0.000100
# 3jtpy5hh  0.667324  0.692249          32       0.000045            0.000329
# 3kmkglwp  0.664659  0.735748          32       0.000025            0.000326
# 3ad0do62  0.664036  0.703996          16       0.000010            0.000300
# xz8bzijt  0.664028  0.742810          16       0.000049            0.000255
# 2xt997wl  0.664020  0.703873          16       0.000050            0.000300
# 2p8sfyt8  0.662716  0.701959          16       0.000052            0.000428
# 21ymy6pl  0.662698  0.703107          16       0.000010            0.000300
# 3gwjpchu  0.662049  0.696577          32       0.000076            0.000490
# 1s11akcf  0.660732  0.747222          16       0.000050            0.000300
# 2grudinm  0.660040  0.693803          16       0.000050            0.000100
# 3mz9cpks  0.659373  0.693226          16       0.000050            0.000100
# 3w4nacko  0.658039  0.688135           8       0.000010            0.000100
# 211od120  0.656672  0.675911          16       0.000100            0.000100
# 3chg60sn  0.656048  0.702019          16       0.000067            0.000405
# 1bzr29sb  0.655802  0.655745          32       0.000050            0.000100
# 1nec0ln7  0.655672  0.719782          16       0.000030            0.000300
# 3926lmpx  0.655555  0.736266          32       0.000050            0.000300
# 11z12asf  0.654726  0.690984          16       0.000030            0.000050
# 1m8ou9gy  0.654691  0.694038          16       0.000012            0.000171
# 3utueic8  0.654057  0.703004          16       0.000041            0.000203
# 2peh20to  0.653712  0.712580          16       0.000030            0.000100
# 2gnfe1ac  0.652938  0.692515          16       0.000050            0.000050
# q9pjprzh  0.652525  0.718586          32       0.000010            0.000300
# rmt2s7k1  0.651978  0.714790          16       0.000058            0.000256
# 3ne9vz94  0.651662  0.716866          32       0.000066            0.000455
# 2naphsvn  0.651606  0.704924          16       0.000021            0.000132
# 3th4m8vd  0.651530  0.654757          32       0.000050            0.000100
#
#                                            wiki_to_vec_file  \
# id
# 189dh04u  /vol/home-vol2/ml/altchris/projects/multi-cone...
# tkoj95qs  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 30h3uizb  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 10cd4j62  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 34bizri5  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 16mclf9r  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 1yfizu0u  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2iwqh41v  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3ktl34lz  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 1nwj2ove  /vol/home-vol2/ml/altchris/projects/multi-cone...
# wtnsnols  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3krpp4o3                                               None
# 1r26cmz0  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2jrs3n6g                                               None
# y94w2aik  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 1d3m9qnz  /vol/home-vol2/ml/altchris/projects/multi-cone...
# vx8lf2w2  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2gkhd1tl  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3699dtwr  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2tkbf0t7  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2tw8n17c  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 1vnj45iv  /vol/home-vol2/ml/altchris/projects/multi-cone...
# i39wwdzc  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3jtpy5hh  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3kmkglwp  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3ad0do62  /vol/home-vol2/ml/altchris/projects/multi-cone...
# xz8bzijt  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2xt997wl  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2p8sfyt8  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 21ymy6pl  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3gwjpchu  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 1s11akcf  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2grudinm  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3mz9cpks  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3w4nacko  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 211od120  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3chg60sn  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 1bzr29sb  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 1nec0ln7  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3926lmpx  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 11z12asf  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 1m8ou9gy  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3utueic8  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2peh20to  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2gnfe1ac  /vol/home-vol2/ml/altchris/projects/multi-cone...
# q9pjprzh  /vol/home-vol2/ml/altchris/projects/multi-cone...
# rmt2s7k1  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3ne9vz94  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 2naphsvn  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 3th4m8vd  /vol/home-vol2/ml/altchris/projects/multi-cone...
#
#           gazetteer_add_output_features  gazetteer_add_input_tokens  \
# id
# 189dh04u                           True                        True
# tkoj95qs                           True                        True
# 30h3uizb                          False                       False
# 10cd4j62                          False                       False
# 34bizri5                          False                       False
# 16mclf9r                           True                       False
# 1yfizu0u                           True                       False
# 2iwqh41v                          False                       False
# 3ktl34lz                          False                       False
# 1nwj2ove                          False                       False
# wtnsnols                           True                        True
# 3krpp4o3                          False                       False
# 1r26cmz0                           True                       False
# 2jrs3n6g                          False                       False
# y94w2aik                           True                        True
# 1d3m9qnz                           True                        True
# vx8lf2w2                           True                       False
# 2gkhd1tl                           True                        True
# 3699dtwr                           True                        True
# 2tkbf0t7                           True                        True
# 2tw8n17c                           True                        True
# 1vnj45iv                           True                        True
# i39wwdzc                           True                        True
# 3jtpy5hh                           True                        True
# 3kmkglwp                           True                        True
# 3ad0do62                           True                        True
# xz8bzijt                           True                        True
# 2xt997wl                           True                        True
# 2p8sfyt8                           True                        True
# 21ymy6pl                           True                        True
# 3gwjpchu                           True                        True
# 1s11akcf                           True                        True
# 2grudinm                           True                        True
# 3mz9cpks                           True                        True
# 3w4nacko                           True                        True
# 211od120                           True                        True
# 3chg60sn                           True                        True
# 1bzr29sb                           True                       False
# 1nec0ln7                           True                        True
# 3926lmpx                           True                        True
# 11z12asf                           True                        True
# 1m8ou9gy                           True                        True
# 3utueic8                           True                        True
# 2peh20to                           True                        True
# 2gnfe1ac                           True                        True
# q9pjprzh                           True                        True
# rmt2s7k1                           True                        True
# 3ne9vz94                           True                        True
# 2naphsvn                           True                        True
# 3th4m8vd                           True                       False
#
#                                              gazetteer_path  augment_input  \
# id
# 189dh04u  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# tkoj95qs  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 30h3uizb                                               None          False
# 10cd4j62                                               None          False
# 34bizri5  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 16mclf9r  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 1yfizu0u  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 2iwqh41v  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 3ktl34lz  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 1nwj2ove  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# wtnsnols  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 3krpp4o3                                               None          False
# 1r26cmz0  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 2jrs3n6g                                               None          False
# y94w2aik  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 1d3m9qnz  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# vx8lf2w2  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 2gkhd1tl  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 3699dtwr  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 2tkbf0t7  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 2tw8n17c  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 1vnj45iv  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# i39wwdzc  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 3jtpy5hh  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 3kmkglwp  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 3ad0do62  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# xz8bzijt  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 2xt997wl  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 2p8sfyt8  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 21ymy6pl  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 3gwjpchu  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 1s11akcf  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 2grudinm  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 3mz9cpks  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 3w4nacko  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 211od120  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 3chg60sn  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 1bzr29sb  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 1nec0ln7  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 3926lmpx  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 11z12asf  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 1m8ou9gy  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 3utueic8  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 2peh20to  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 2gnfe1ac  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# q9pjprzh  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# rmt2s7k1  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 3ne9vz94  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
# 2naphsvn  /vol/home-vol2/ml/altchris/projects/multi-cone...          False
# 3th4m8vd  /vol/home-vol2/ml/altchris/projects/multi-cone...           True
#
#           augment_input_prob  use_mlp  mlp_hidden_dim  mlp_num_layers  \
# id
# 189dh04u            0.300000     True            1024               2
# tkoj95qs            0.200000     True            1024               2
# 30h3uizb            0.200000     True            1024               2
# 10cd4j62            0.200000     True            1024               2
# 34bizri5            0.200000     True            1024               2
# 16mclf9r            0.200000     True            1024               2
# 1yfizu0u            0.200000     True            1024               2
# 2iwqh41v            0.200000     True            1024               2
# 3ktl34lz            0.200000     True            1024               2
# 1nwj2ove            0.200000     True            1024               2
# wtnsnols            0.200000     True            1024               2
# 3krpp4o3            0.200000     True            1024               2
# 1r26cmz0            0.200000     True            1024               2
# 2jrs3n6g            0.200000     True            1024               2
# y94w2aik            0.200000     True            1024               2
# 1d3m9qnz            0.323977     True             128               2
# vx8lf2w2            0.200000     True            1024               2
# 2gkhd1tl            0.142144     True             512               2
# 3699dtwr            0.230234     True            1024               2
# 2tkbf0t7            0.200000     True            1024               2
# 2tw8n17c            0.138387     True             512               2
# 1vnj45iv            0.211416     True            1024               2
# i39wwdzc            0.200000     True            1024               2
# 3jtpy5hh            0.261817     True             128               2
# 3kmkglwp            0.226294     True            1024               2
# 3ad0do62            0.200000     True            1024               2
# xz8bzijt            0.126006     True            1024               2
# 2xt997wl            0.300000     True            1024               2
# 2p8sfyt8            0.324056     True             128               2
# 21ymy6pl            0.300000     True            1024               2
# 3gwjpchu            0.303388     True             128               2
# 1s11akcf            0.200000     True            1024               2
# 2grudinm            0.200000     True            1024               2
# 3mz9cpks            0.300000     True            1024               2
# 3w4nacko            0.200000     True            1024               2
# 211od120            0.200000     True            1024               2
# 3chg60sn            0.351576     True             128               2
# 1bzr29sb            0.200000     True            1024               2
# 1nec0ln7            0.200000     True            1024               2
# 3926lmpx            0.200000     True            1024               2
# 11z12asf            0.200000     True            1024               2
# 1m8ou9gy            0.226998     True             512               2
# 3utueic8            0.175424     True             512               2
# 2peh20to            0.300000     True            1024               2
# 2gnfe1ac            0.300000     True            1024               2
# q9pjprzh            0.200000     True            1024               2
# rmt2s7k1            0.263506     True            1024               2
# 3ne9vz94            0.485859     True             256               2
# 2naphsvn            0.186278     True             512               2
# 3th4m8vd            0.200000     True            1024               2
#
#                           model_name_or_path
# id
# 189dh04u  google/electra-large-discriminator
# tkoj95qs  google/electra-large-discriminator
# 30h3uizb  google/electra-large-discriminator
# 10cd4j62  google/electra-large-discriminator
# 34bizri5  google/electra-large-discriminator
# 16mclf9r  google/electra-large-discriminator
# 1yfizu0u  google/electra-large-discriminator
# 2iwqh41v  google/electra-large-discriminator
# 3ktl34lz  google/electra-large-discriminator
# 1nwj2ove  google/electra-large-discriminator
# wtnsnols  google/electra-large-discriminator
# 3krpp4o3  google/electra-large-discriminator
# 1r26cmz0  google/electra-large-discriminator
# 2jrs3n6g  google/electra-large-discriminator
# y94w2aik  google/electra-large-discriminator
# 1d3m9qnz  google/electra-large-discriminator
# vx8lf2w2  google/electra-large-discriminator
# 2gkhd1tl  google/electra-large-discriminator
# 3699dtwr  google/electra-large-discriminator
# 2tkbf0t7  google/electra-large-discriminator
# 2tw8n17c  google/electra-large-discriminator
# 1vnj45iv  google/electra-large-discriminator
# i39wwdzc  google/electra-large-discriminator
# 3jtpy5hh  google/electra-large-discriminator
# 3kmkglwp  google/electra-large-discriminator
# 3ad0do62  google/electra-large-discriminator
# xz8bzijt  google/electra-large-discriminator
# 2xt997wl  google/electra-large-discriminator
# 2p8sfyt8  google/electra-large-discriminator
# 21ymy6pl  google/electra-large-discriminator
# 3gwjpchu  google/electra-large-discriminator
# 1s11akcf  google/electra-large-discriminator
# 2grudinm  google/electra-large-discriminator
# 3mz9cpks  google/electra-large-discriminator
# 3w4nacko  google/electra-large-discriminator
# 211od120  google/electra-large-discriminator
# 3chg60sn  google/electra-large-discriminator
# 1bzr29sb  google/electra-large-discriminator
# 1nec0ln7  google/electra-large-discriminator
# 3926lmpx  google/electra-large-discriminator
# 11z12asf  google/electra-large-discriminator
# 1m8ou9gy  google/electra-large-discriminator
# 3utueic8  google/electra-large-discriminator
# 2peh20to  google/electra-large-discriminator
# 2gnfe1ac  google/electra-large-discriminator
# q9pjprzh  google/electra-large-discriminator
# rmt2s7k1  google/electra-large-discriminator
# 3ne9vz94  google/electra-large-discriminator
# 2naphsvn  google/electra-large-discriminator
# 3th4m8vd  google/electra-large-discriminator

# %%
RESULTS = [
    {
        "name": "Gazetteer (late fusion)",
        "runs": ["xxe8qlir", "42ogdhvi", "1364qxbs"],
    },
    {
        "name": "Wiki2Vec (late fusion)",
        "runs": ["3npv5i5s", "s1liftjn", "310zj25k"],
    },
    {
        "name": "ELECTRA-large",
        "runs": ["8a2vrshm", "2jrs3n6g", "3krpp4o3"],
    },
    {
        "name": "ELECTRA-large + Wiki2Vec (late fusion)",
        "runs": ["1jhy0qpd", "2jrs3n6g", "3krpp4o3"],
    }
]

# %%
df.loc[RESULTS[1]["runs"]][[
    "val/f1", "val/orig/f1-score", "val/augm/f1-score", "train/f1", "epoch", "batch_size", "learning_rate", "task_learning_rate", "wiki_to_vec_file",
    "gazetteer_add_output_features", "gazetteer_add_input_tokens", "gazetteer_path", "augment_input", "augment_input_prob", "use_mlp",
    "mlp_hidden_dim", "mlp_num_layers", "model_name_or_path", "use_span_length_embedding", "use_language_model"]]
# Out:
#             val/f1  val/orig/f1-score  val/augm/f1-score  train/f1  epoch  \
# id
# 3npv5i5s  0.574447           0.552203           0.563267  0.560703     24
# s1liftjn  0.580069           0.559592           0.569615  0.569062     26
# 310zj25k  0.616813           0.598637           0.608978  0.614132     44
#
#           batch_size  learning_rate  task_learning_rate  \
# id
# 3npv5i5s          32        0.00001             0.00005
# s1liftjn          32        0.00001             0.00005
# 310zj25k          32        0.00001             0.00005
#
#                                            wiki_to_vec_file  \
# id
# 3npv5i5s  /vol/home-vol2/ml/altchris/projects/multi-cone...
# s1liftjn  /vol/home-vol2/ml/altchris/projects/multi-cone...
# 310zj25k  /vol/home-vol2/ml/altchris/projects/multi-cone...
#
#           gazetteer_add_output_features  gazetteer_add_input_tokens  \
# id
# 3npv5i5s                          False                       False
# s1liftjn                          False                       False
# 310zj25k                          False                       False
#
#          gazetteer_path  augment_input  augment_input_prob  use_mlp  \
# id
# 3npv5i5s           None          False                 0.2     True
# s1liftjn           None          False                 0.2     True
# 310zj25k           None          False                 0.2     True
#
#           mlp_hidden_dim  mlp_num_layers                  model_name_or_path  \
# id
# 3npv5i5s            1024               2  google/electra-large-discriminator
# s1liftjn            1024               2  google/electra-large-discriminator
# 310zj25k            1024               2  google/electra-large-discriminator
#
#          use_span_length_embedding use_language_model
# id
# 3npv5i5s                     False              False
# s1liftjn                     False              False
# 310zj25k                     False              False
